# %%
import cv2
from classify import cnn_model_fn,input_fn,label_dict,image_size
import tensorflow as tf
import numpy as np
from mtcnn.mtcnn import MTCNN

fer_pre_trained_model = '/Users/vimal/git/fer/output/20190125-110715/'
face_expression_classifier = tf.estimator.Estimator(model_fn=cnn_model_fn,warm_start_from=fer_pre_trained_model)
detector = MTCNN()
video = cv2.VideoCapture(0)
while True:
    # Capture frames
    _, frame = video.read()
    # Use MTCNN for detecting faces
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = detector.detect_faces(frame)
    if result != []:
        for person in result:
            bounding_box = person['box']
            keypoints = person['keypoints']
            
            x = bounding_box[0]
            y = bounding_box[1]
            w = bounding_box[0]+bounding_box[2]
            h = bounding_box[1]+bounding_box[3]
            
            face_image = frame[y:h, x:w]
            #face_image = cv2.cvtColor(face_image,cv2.IMREAD_GRAYSCALE)
            face_image = cv2.resize(face_image,(image_size,image_size))
            #file_name = "/Users/vimal/git/fer/test/face_" + str(y) + ".jpg"
            #cv2.imwrite(file_name, face_image)
            face_image = np.array(face_image,dtype=np.float32)
            predict_results = face_expression_classifier.predict(input_fn=lambda: input_fn(np.array([face_image])))
            #expression=''
            for predict in predict_results:
                expression = label_dict[np.argmax(predict['probabilities'])]
                print(expression)
            
            #file_name = "/Users/vimal/git/fer/test/face_" + str(y) + ".jpg"
            #cv2.imwrite(file_name, face_image)
            
            #cv2.circle(frame,(keypoints['left_eye']),2,(0,155,155),2)
            #cv2.circle(frame,(keypoints['right_eye']),2,(0,155,155),2)
            #cv2.circle(frame,(keypoints['nose']),2,(0,155,155),2)
            #cv2.circle(frame,(keypoints['mouth_left']),2,(0,155,155),2)
            #cv2.circle(frame,(keypoints['mouth_right']),2,(0,155,155),2)
            # display resulting frame
            cv2.rectangle(frame,(x,y),(w,h),(0,155,155),2)
            cv2.putText(frame,expression,(x,y),cv2.FONT_HERSHEY_SIMPLEX,1.0,(0,155,155))
            cv2.imshow('frame',frame)
            if cv2.waitKey(1) &0xFF == ord('q'):
                break
video.release()
cv2.destroyAllWindows()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12b67bb38>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# happy
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# happy
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# happy
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# surprise
# ...
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/bias; prev_var_name: Unchanged
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# neutral
# INFO:tensorflow:Could not find trained model in model_dir: /var/folders/y3/d9nfl45x7p765ck8c1v_hlsc0000gp/T/tmpi03u8bay, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/Users/vimal/git/fer/output/20190125-110715/', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('/Users/vimal/git/fer/output/20190125-110715/',)
# INFO:tensorflow:Warm-starting variable: conv2d/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_4/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_5/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_6/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_7/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_8/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv2d_9/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: logits/kernel; prev_var_name: Unchanged
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-600bd3138236> in <module>
#      33             predict_results = face_expression_classifier.predict(input_fn=lambda: input_fn(np.array([face_image])))
#      34             #expression=''
# ---> 35             for predict in predict_results:
#      36                 expression = label_dict[np.argmax(predict['probabilities'])]
#      37                 print(expression)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in predict(self, input_fn, predict_keys, hooks, checkpoint_path, yield_single_examples)
#     578
#     579         # Call to warm_start has to be after model_fn is called.
# --> 580         self._maybe_warm_start(checkpoint_path)
#     581
#     582         predictions = self._extract_keys(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _maybe_warm_start(self, checkpoint_path)
#    1610       logging.info('Warm-starting with WarmStartSettings: %s' %
#    1611                    (self._warm_start_settings,))
# -> 1612       warm_starting_util.warm_start(*self._warm_start_settings)
#    1613
#    1614
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/warm_starting_util.py in warm_start(ckpt_to_initialize_from, vars_to_warm_start, var_name_to_vocab_info, var_name_to_prev_var_name)
#     461         if len(variable) == 1:
#     462           variable = variable[0]
# --> 463         _warm_start_var(variable, ckpt_to_initialize_from, prev_var_name)
#     464
#     465   prev_var_name_not_used = set(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/warm_starting_util.py in _warm_start_var(var, prev_ckpt, prev_tensor_name)
#     179     # Assume tensor name remains the same.
#     180     prev_tensor_name = current_var_name
# --> 181   checkpoint_utils.init_from_checkpoint(prev_ckpt, {prev_tensor_name: var})
#     182
#     183
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/checkpoint_utils.py in init_from_checkpoint(ckpt_dir_or_file, assignment_map)
#     185   else:
#     186     distribution_strategy_context.get_tower_context().merge_call(
# --> 187         _init_from_checkpoint, ckpt_dir_or_file, assignment_map)
#     188
#     189
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/distribute.py in merge_call(self, merge_fn, *args, **kwargs)
#    1051     """
#    1052     require_tower_context(self)
# -> 1053     return self._merge_call(merge_fn, *args, **kwargs)
#    1054
#    1055   def _merge_call(self, merge_fn, *args, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/distribute.py in _merge_call(self, merge_fn, *args, **kwargs)
#    1059             self._distribution_strategy))
#    1060     try:
# -> 1061       return merge_fn(self._distribution_strategy, *args, **kwargs)
#    1062     finally:
#    1063       _pop_per_thread_mode()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/checkpoint_utils.py in _init_from_checkpoint(_, ckpt_dir_or_file, assignment_map)
#     192
#     193   ckpt_file = _get_checkpoint_filename(ckpt_dir_or_file)
# --> 194   reader = load_checkpoint(ckpt_dir_or_file)
#     195   variable_map = reader.get_variable_to_shape_map()
#     196   for tensor_name_in_ckpt, current_var_or_name in sorted(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/training/checkpoint_utils.py in load_checkpoint(ckpt_dir_or_file)
#      62     raise ValueError("Couldn't find 'checkpoint' file or checkpoints in "
#      63                      "given directory %s" % ckpt_dir_or_file)
# ---> 64   return pywrap_tensorflow.NewCheckpointReader(filename)
#      65
#      66
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in NewCheckpointReader(filepattern)
#     324   with errors.raise_exception_on_not_ok_status() as status:
#     325     from tensorflow.python.util import compat
# --> 326     return CheckpointReader(compat.as_bytes(filepattern), status)
#     327
#     328 NewCheckpointReader._tf_api_names = ['train.NewCheckpointReader']
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in __init__(self, filepattern, out_status)
#     337
#     338     def __init__(self, filepattern, out_status):
# --> 339         this = _pywrap_tensorflow_internal.new_CheckpointReader(filepattern, out_status)
#     340         try:
#     341             self.this.append(this)
#
# KeyboardInterrupt:
